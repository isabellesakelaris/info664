# %% [markdown]
# # Week 2 - Python Basics #
# **Name:** Isabelle Sakelaris\
# **Date:** August 31, 2026

# %% [markdown]
# ### Notes from Slides ###

# %% [markdown]
# *Functions*
# - Functions are followed by parentheses
# - Functions have parameters, placed inside the parentheses
# - Some functions have more than one parameter, which are separated by commas: pow(base, exp)

# %% [markdown]
# *Strings*
# - Strings are denoted by single or double quotes: print("hello")
# - Strings are text data

# %% [markdown]
# *Variables*
# - python uses = to give variables a value
# - name = "Isabelle" assigns the string "Isabelle" to the value name
# - Note that == is used to test for equivalence and != is for inequivalence

# %% [markdown]
# *Indentations*
# - Python uses indentation for conditional formatting, defining functions, and for loops
# - Put a colon at the end of your conditional statement and indent the next line

# %% [markdown]
# *Comments*
# - Comments use a pound symbol at the beginning
# - Comments can also be placed after a functional line of code: print("hello, world!") #this is a comment
# - Use comments to explain things that aren't readily apparent, for decisions about why you did things, etc.

# %% [markdown]
# ### Hello world
# This is the print function, which will display a string that I input.

# %%
print("hello world") #this is my print function
# Out:
# hello world

# %% [markdown]
# *Note:* Python is case-sensitive, so don't use uppercase for built-in functions! ex., Print("hello world") will throw an error with a hint about what's wrong.

# %% [markdown]
# ### Data Types in Python ###

# %% [markdown]
# There are a few different data types in Pythonn, including int (whole numbers), float(non-whole numbers), string (text characters), and bool (true/false).

# %% [markdown]
# There is a function called type(), which tells you what data type the parameter within is. Example below:

# %%
print(type(5)) # int
print(type(5.5)) # float
print(type("5")) # str
print(type(True)) # boolean, but also note that true must be capitalized
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %% [markdown]
# *Note:* When nesting functions, the innermost function will execute first.

# %% [markdown]
# ### Comparison Operators ###
# - Comparison operators are symbols that compare whether things are True or False (ex. equivalence, greater than and less than)

# %%
print(5 > 3) # This is a greater than operator
# Out:
# True

# %%
print(5 == 5) # This is an equal-to operator
# Out:
# True

# %%
print(5 != 5) # This is an inequality operator
# Out:
# False

# %%
print(5 <= 3) # This is a less than or equal-to operator
# Out:
# False

# %% [markdown]
# We can compare strings as well.

# %%
print("hello" == "hello") #these are the same
# Out:
# True

# %%
print("apple" < "banana") #this is true because a comes before b in the alphabet
# Out:
# True

# %% [markdown]
# There are **string methods**, which we will get to later, to help with other types of string comparisons.

# %% [markdown]
# ### Arithmetic Operators ###

# %% [markdown]
# - These are for doing math with data (+, -, /, *)

# %%
print(1 + 1) #addition
# Out:
# 2

# %%
print(7-2) #subtraction
# Out:
# 5

# %%
print(4*4) #multiplication
# Out:
# 16

# %%
print(6/2) #"true" division, which results in a float (so that it can be a decimal)
print(6//2) #"floor" division, which rounds down the result into the nearest integer
# Out:
# 3.0
# 3

# %%
print(7%2) #modulo, which gives a remainder.
# Out:
# 1

# %% [markdown]
# *Note*: If modulo%2 is equal to 0, the number is even. If modulo%2 is 1, the number is odd.

# %%
print(7**2) #exponent
# Out:
# 49

# %% [markdown]
# ### Variable Declaration ###
# - Variables are keywords that represent other data
# - Variables can be declared using the = symbol.
# - The word on the left is the name of the variable, and its value is on the right.
# - Anywhere below the line where the variable is assigned will remember the variable's value.

# %%
name = "Isabelle" #assigning the variable 'name' as the string 'Isabelle'
print(name) #will show my name!
# Out:
# Isabelle

# %%
age = 29 #assigning the variable 'age' as the integer 29
print(age) #this will show my age!
# Out:
# 29

# %% [markdown]
# ### Naming Conventions for Variables ###
# - Give your variable a name that describes its value
# - names **can't** start with a number
# - names **can't** have a hyphen in them
# - names **can** have underscores in them. We put underscores where a space would go in natural language
# - names **can't** use "if" and "for", because those are special words in Python
# - uppercase designates a constant variable that will not change after it is set—this is a stylistic thing

# %% [markdown]
# ### Incrementing and Modifying Variables ###
# - Variables can get new values, and they can be modified by functions and arithmetic operators.

# %%
age = 29
age = age*2
print(age)
# Out:
# 58

# %%
age += 1 #ran this cell before adding the print function, so it shows 62 now, but += is shorthand for adding one
print(age)
# Out:
# 59

# %% [markdown]
# ### Converting Data Types ###
# - Data can be converted from one type to another using conversion functions!
# - It can be really helpful if you're comparing data
# - A lot of data comes as raw text

# %%
pi = 3.14159
print(pi)
pi_as_string = str(pi) #str() converts to a string
print(type(pi_as_string)) #this will confirm the new variable is a string
pi_as_float = float(pi_as_string)
print(pi_as_float)
print(type(pi_as_float))

#print(pi_as_string>3) #here I get an error sayign you can't compare a string to a number
print(pi_as_float>3) #here it will work
# Out:
# 3.14159
# <class 'str'>
# 3.14159
# <class 'float'>
# True

# %% [markdown]
# ### All about Strings ###
# Below is a multi-line string:

# %%
# triplequotaitons bind multi-line strings
poem = """Roses are red
violets are blue
I love programming in 'Python'
and I love you!""" #this can be a single quote or a double quote, but be aware of apostrophes and quotation marks in your data
print(poem)
# Out:
# Roses are red
# violets are blue
# I love programming in 'Python'
# and I love you!

# %%
good = "I'm having a good day"
print(good)
# bad = 'i'm having a good day'
# print(bad) #it won't print, there'll be an error
# Out:
# I'm having a good day

# %% [markdown]
# **Note:** Curly quotes will work, but can be confusing visually. You can use """ """ to create a string with curly quotes, example below:

# %%
good_example = """“Hello”"""
print(good_example)
# Out:
# “Hello”

# %% [markdown]
# ### Combining and Concatenating ###
# Strings can be comgined with the plus sign.
# - Strings can only be concatenated with strings
# - F-strings are good for formatting strings

# %%
dog_name = "Duke"
dog_age = 9
# below we need to change the int to a string here (like combines with like)
my_dog = "My dog's name is " + dog_name + " and he is " + str(dog_age)
print(my_dog)
# Out:
# My dog's name is Duke and he is 9

# %%
# with F strings, you don't need to convert the int to a string beforehand
my_dog = f"My dog's name is {dog_name}. He is {dog_age}."
print(my_dog)
# Out:
# My dog's name is Duke. He is 9.

# %% [markdown]
# ### Converting String Cases ###
# - This is useful for when words appear in uppercase and lowercase across a dataset
# - Here we will see a string "method," which is function dealing with a specific data type or class.
# - There are built in string methods fro converting to upper, lower, capitalized, and title case

# %%
print(dog_name.upper())
print(dog_name.lower())
print(my_dog.title()) #not real title case in the stylistic sense!
print(my_dog.capitalize()) #capitalizes only the first letter of the string
# Out:
# DUKE
# duke
# My Dog'S Name Is Duke. He Is 9.
# My dog's name is duke. he is 9.

# %% [markdown]
# **Note:** These methods don't need parameters, but you still need the parentheses.

# %% [markdown]
# ### Searching, Extracting, and Counting in a String ###
# - Some string methods deal with searching for substrings, etc.
# - The keyword **in** will evaluate true/false if something is contained within a string.

# %%
print("cat" in my_dog) #will print false, since "cat" is not in the string.
print("dog" in my_dog) #will print true, since "dog" is in the string.
# Out:
# False
# True

# %%
my_dog = my_dog + " I really love dogs and dogs are my best friends"
print(my_dog)
# Out:
# My dog's name is Duke. He is 9. I really love dogs and dogs are my best friends

# %%
dog_count = my_dog.count("dog")
print(dog_count) #will print three
print(f"The word 'dog' appears {dog_count} times.") #will print the whole sentence!
# Out:
# 3
# The word 'dog' appears 3 times.

# %%
cat_count = my_dog.count("cat")
print(f"The word 'cat' appears {cat_count} times.")
# Out:
# The word 'cat' appears 0 times.

# %% [markdown]
# # Homework 1 #

# %% [markdown]
# I took the following text from Wikipedia's featured image on September 13th.

# %% [markdown]
# The salema porgy (Sarpa salpa) is a species of marine ray-finned fish in the seabream and porgy family, Sparidae. It has a silvery body with eight to ten horizontal golden lines and a black spot at the base of the pectoral fin, and can sometimes reach more than 50 cm (20 in) in length. The species occurs in the eastern Atlantic from the Bay of Biscay to South Africa, as well as the Mediterranean Sea, at depths of up to 70 m (230 ft). It is largely herbivorous, feeding principally on seagrasses and algae, and is a protandrous hermaphrodite, changing from male to female. Consumption can sometimes cause ichthyoallyeinotoxism poisoning, resulting in auditory and visual hallucinations.

# %%
name = "salema porgy"
sci_name = "Sarpa salpa"
family = "Spaidae"
length_cm = 50
length_in = 20
depth_m = 70
depth_ft = 239
condition = "ichthyoallyeinotoxism poisoning"

# %%
print(f"The {name} ({sci_name}) is a species of marine ray-finned fish in the seabream and porgy family, {family}. It has a silvery body with eight to ten horizontal golden lines and a black spot at the base of the pectoral fin, and can sometimes reach more than {length_cm} cm ({length_in} in) in length. The species occurs in the eastern Atlantic from the Bay of Biscay to South Africa, as well as the Mediterranean Sea, at depths of up to {depth_m} m ({depth_ft} ft). It is largely herbivorous, feeding principally on seagrasses and algae, and is a protandrous hermaphrodite, changing from male to female. Consumption can sometimes cause {condition}, resulting in auditory and visual hallucinations.")
# Out:
# The salema porgy (Sarpa salpa) is a species of marine ray-finned fish in the seabream and porgy family, Spaidae. It has a silvery body with eight to ten horizontal golden lines and a black spot at the base of the pectoral fin, and can sometimes reach more than 50 cm (20 in) in length. The species occurs in the eastern Atlantic from the Bay of Biscay to South Africa, as well as the Mediterranean Sea, at depths of up to 70 m (239 ft). It is largely herbivorous, feeding principally on seagrasses and algae, and is a protandrous hermaphrodite, changing from male to female. Consumption can sometimes cause ichthyoallyeinotoxism poisoning, resulting in auditory and visual hallucinations.

# %% [markdown]
# # Homework 2 #

# %% [markdown]
# The following text comes from [this CNN article](https://www.cnn.com/2026/09/13/politics/trump-administration-ai-legislation).

# %%
article = "The latest warnings about AI seem intended to boggle minds and shock everyone into action. Anthropic CEO Dario Amodei, a leader in the AI race, on Saturday called for a conscious slowdown in AI development in an essay posted to his website. AI is developing faster and faster and could outrun humans’ ability to manage it, he wrote. “Left unchecked, it could outrun our ability to understand and control these systems, and so must be pursued very carefully, if at all,” Amodei wrote. The call for action comes just days after a former engineer at Amodei’s company went even further, saying AI could bring about the end of humanity. “The people building AI earnestly believe that it could kill us all by the end of the decade,” said Jacob Coxon, who had worked at both OpenAI and Anthropic before he posted his viral warning on social media. Nobody knows how exactly AI would end humanity, as Coxon explained to CNN’s Anderson Cooper. The argument is that AI is getting smarter all the time and will soon make itself smarter on its own, be able to outwit humans and unleash … something. Hack nuclear weapons? Let loose a devastating virus? Plunge the world into darkness? Create a lame society in which unfulfilled people can’t find work? Take your pick. It should be comforting, maybe, that while the Pentagon is relying on artificial intelligence, Secretary of Defense Pete Hegseth has said, “AI is not making lethal decisions.” Beyond that, the law does not place explicit limits on where AI can be used in the so-called kill chain. Coxon’s message was amplified by public interest groups and lawmakers looking to heed the advice of the AI companies that want the government to impose a framework and limits on how AI is developed. Companies such as Anthropic and OpenAI have publicly called for the government to regulate them so it can slow down their current race for AI domination, which coincides with their race to initial public offerings. What we’re seeing is “a very small and powerful group of companies, linked arms together, running toward what they say is a cliff they cannot seem to stop themselves from running off,” the tech journalist and CNN contributor Jacob Ward told CNN’s Kasie Hunt on Thursday. He argued that calls from these people who are in the process of making a lot of money should not be ignored. “They are saying, ‘Hey, we’re building this thing, and it’s exciting, but it might not just cost you your job, but your life.’ I think it is important that we start paying attention,” Ward said. Among those calling for government action is Sen. Bernie Sanders, who takes the warnings seriously. “Nearly every day, there is a frightening new story about how Big Tech companies are losing control of the technology they are developing, with potentially cataclysmic results,” Sanders said in announcing proposed legislation to ban artificial superintelligence. “It is irresponsible for society to allow them to move forward and make these products even more advanced.” Sanders also talked about his proposal with CNN’s Kaitlan Collins. David Sacks, a tech investor who is also co-chair of President Trump’s Council of Advisors on Science and Technology, has pushed in the other direction, toward an open market-based approach to AI. Appearing on Fox News Thursday, Sacks questioned Coxon’s motivations and seeded the idea that his warning was part of a conspiracy by “doomers,” maybe financed by China, to thwart AI innovation in the US. On Saturday, President Donald Trump echoed that sentiment, saying during a news briefing in Ireland that people worried about the ultimate impacts of AI “are bringing up things that won’t happen.” Asked whether the industry needs to be regulated, Trump said repeated his earlier statement about competing with China. “We’re leading China in AI,” he said. “We’re the most sophisticated country in the world, and frankly, I want to keep it that way, because whoever wins AI wins. And we can put guard rails.” Sacks is among those who argued American companies must continue to innovate rather than allow China to achieve AI supremacy. “They don’t have this giant influence operation of these doomer groups in China,” Sacks told Fox News’ Bret Baier. “What we have here in the US, though, is we have this huge media campaign against AI and it is turning the public against AI.” Sacks added of China: “They would love for us to stop AI development over here.” In a video from his “All-In” podcast, which Sacks posted to his account on X, he argued the AI companies want regulation so that they can effectively control AI. He called it a “frontier market duopoly.” Government officials aren’t going to have any idea how to regulate AI, he argued. “So they’re going to turn to the leading labs to say, ‘Hey, how should we regulate it?’ And of course, Anthropic is going to have all the answers on that,” he said, suggesting warnings of AI run amok are part of a play for market domination. Rather than push the idea that AI has the potential to end humanity, Sacks sees a conspiracy to place power over AI in a few select hands. That, he said in another X post, would be the true danger. “Keeping innovation decentralized and accessible is the key to avoiding an unsafe and dystopian future where advanced AI capabilities are centralized and controlled by only a few hands,” he said. That kind of mindset is in line with Trump’s efforts to stop states like California from imposing their own AI regulations in the absence of movement from Washington. When efforts to ban state regulations stalled in Congress last year, Trump signed an executive action trying to do the same thing. The Trump administration has so far viewed AI regulation more as part of a race with China over the technology than as an effort to protect humanity, as CNN’s Hadas Gold explained in her recent story, ‘It feels a little like early Covid’: The messy scramble to regulate AI. The administration blocked export of some Nvidia chips to China, for instance, or temporarily delayed release of products to assess their impact on national security. To those who see existential danger in AI, all of this may echo the nuclear arms race of the Cold War, when countries ultimately set aside differences to impose a series of treaties in the 1960s and beyond for Nuclear Non-proliferation, test bans, strategic arms limitations, and more. But it’s hard to imagine the Trump administration — or China — getting involved in any worldwide treaty effort, although Europe has tried to go the route of a treaty for AI regulations. The threat posed by nuclear weapons still animates US foreign policy and is a main reason cited by Trump for his war on Iran. While the most dire warnings about AI have to do with the end of humanity, it is most potent as an issue motivating voters worried about AI encroaching in their backyards. Americans are unnerved at unsightly data centers that power the hive mind of AI and which tech giants would have dot the landscape, impacting water quality, driving up energy bills, and swallowing up farmland."

# %%
print(article) #checking to ensure the formatted quotes are working as expected in the variable
# Out:
# The latest warnings about AI seem intended to boggle minds and shock everyone into action. Anthropic CEO Dario Amodei, a leader in the AI race, on Saturday called for a conscious slowdown in AI development in an essay posted to his website. AI is developing faster and faster and could outrun humans’ ability to manage it, he wrote. “Left unchecked, it could outrun our ability to understand and control these systems, and so must be pursued very carefully, if at all,” Amodei wrote. The call for action comes just days after a former engineer at Amodei’s company went even further, saying AI could bring about the end of humanity. “The people building AI earnestly believe that it could kill us all by the end of the decade,” said Jacob Coxon, who had worked at both OpenAI and Anthropic before he posted his viral warning on social media. Nobody knows how exactly AI would end humanity, as Coxon explained to CNN’s Anderson Cooper. The argument is that AI is getting smarter all the time and will
# ...

# %%
term1_count = article.count("AI")
print(term1_count)
term2_count = article.count("Sacks")
print(term2_count)
# Out:
# 39
# 7

# %%
string = "Frequency of term 1: " + term1_count + ". Frequency of term 2: " + term2_count + "." #this didn't work because count outputs an integer!
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 string = "Frequency of term 1: " + term1_count + ". Frequency of term 2: " + term2_count + "." #this didn't work because count outputs an integer!
#
# TypeError: can only concatenate str (not "int") to str

# %%
string = "Frequency of term 1: " + str(term1_count) + ". Frequency of term 2: " + str(term2_count) + "."

# %%
print(string)
# Out:
# Frequency of term 1: 39. Frequency of term 2: 7.

# %% [markdown]
# # Homework 3 #
# I like Giorgia's week 7 "musical complaints" dataset, because I thought it was creative to make a musical score out of data, especially something negative, like complaints. I thought tracking "actual need to complain" was interesting, too, because it is subjective. However, I thought that was a good way to include duration in the musical dataset.
#
# I also enjoyed Giorgia's first week, where she tracked each time she looked at a clock. I liked how she included her thoughts, for exmaple, about being late, as well as what kind of clock she saw. The image she created was a little less legible for me, despite the key. I still enjoyed the visualization, though.

# %% [markdown]
# **My data: emails**
# I kept track of all the emails I received to my Pratt email address. Each time I received an email, I moved it into a folder where I could later reivew them all at once. I decided to track the sender, email type (work or school-related, personal, marketing, transactional, and listserv). The subject line and date of receipt were automatically tracked as well.

# %% [markdown]
# Pratt emails
# - Residential Life office, marketing
# - no-reply, listserv
# - Museum-L, listserv
# - Epicurious, marketing/work
# - ALA JobsList, listserv
# - Anisha Vonna, listserv
# - Center For Book Arts, marketing
# - United Healthcare, transactional
# - Kathleen McCook, listserv
# - Epicurious, marketing/work
# - ALA JobsList, listserv
# - ARLIS-L, listserv
# - Athletics And Recreation, listserv
# - ARLIS-L, listserv
# - Kathleen McCook, listserv
# - Annette Macias, listserv
# - History of Art And Design Dept, listserv
# - Kathleen McCook, listserv
# - Kathleen McCook, listserv
# - ALA JobsList, listserv
# - ARLIS-L, listserv
# - Museum-L, listserv
# - Museum-L, listserv
# - Canvas, transactional/school related
# - ARLIS-L, listserv
# - Anisha Vonna, listserv
# - History of Art And Design Dept, listserv
# - ALA JobsList, listserv
# - Student Financial Services, transactional
# - Pratt Now, listserv
# - Pratt ALA, listserv
# - John Gant, listserv
# - ARLIS-L, listserv
# - ARLIS-L, listserv
# - Museum-L, listserv
# - MuseWeekly, listserv
# - Epicurious, marketing/work
# - ARLIS-L, listserv
# - ARLIS-L, listserv
# - Epicurious, marketing/work
# - ALA, marketing
# - ALA JobsList, listserv
# - ARLIS-L, listserv
# - Kaeli Gretter, listserv
# - Museum-L, listserv
# - ARLIS-L, listserv
# - ARLIS-L, listserv
# - PEMP, listserv
# - Pratt, listserv
# - ARLIS-L, listserv
# - Handshake, marketing
# - Museum-L, listserv
# - ARLIS-L, listserv
# - Harsh Taggar, listserv
# - ARLIS-L, listserv
# - History of Art And Design Dept, listserv
# - History of Art And Design Dept, listserv
# - Pratt SAA, listserv
# - Pratt SAA, listserv
# - Design Tutor, listserv
# - Xin Jiang, listserv
# - Kathleen McCook, listserv
# - ALA JobsList, listserv
# - Mega Subramaniam, listserv
# - Handshake, marketing
# - ARLIS-L, listserv
# - RM, listserv
# - Pratt Institute, marketing
# - Office of institutional equity / Title IX, listserv
# - Residential Life Office, marketing
# - Manuela Aronofsky, listserv
# - NYFA classifieds, marketing
# - Pratt Info School, listserv
# - Pratt Career Success, marketing
# - Pratt Info School, listserv
# - Dean of the school of architecture, marketing
# - Student involvement office, marketing
# - Anthony Cocciolo, listserv
# - Gerard Samson, listserv
# - Pratt Info School, listserv
# - Pratt Institute Libraries, listserv
# - ARLIS-L, listserv
# - A + Ae Portal, marketing
# - Epicurious, marketing/work
# - ALA JobsList, listserv
